# %% [markdown]
# # Imports and setup

# %%
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
from plotly import __version__

# %%
import cufflinks as cf

# %%
from plotly.offline import download_plotlyjs,init_notebook_mode,plot,iplot

# %%
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# # Creating Data

# %%
df=pd.DataFrame(np.random.randn(101,4),columns='A B C D'.split())

# %%
df.head()
# Out:
#           A         B         C         D
# 0  0.304897  1.546660  0.250981 -0.064638
# 1 -0.598895 -1.164442 -0.695227 -0.647245
# 2  1.166892  0.248286  0.577253 -0.797727
# 3 -0.475130 -2.040725 -0.508089 -0.639552
# 4 -0.642102 -0.740415 -1.143173  0.240190

# %%
df2 = pd.DataFrame({'Category':['A','B','C'],'Values':[32,43,50]})

# %%
df2
# Out:
#   Category  Values
# 0        A      32
# 1        B      43
# 2        C      50

# %% [markdown]
# # Creating a line plot

# %%
df.iplot(xTitle='Index',yTitle='Value',title='Line plot Df')
# Out:
# <div>
#
#
#             <div id="cb65f243-3c6e-4ef0-b949-fad9c6048195" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("cb65f243-3c6e-4ef0-b949-fad9c6048195")) {
#                     Plotly.newPlot(
#                         'cb65f243-3c6e-4ef0-b949-fad9c6048195',
# ...

# %% [markdown]
# # Creating a scatter plot

# %%
#Note: Mode='markers' is needed because by default iplot will connect each value in the data set with a line
df.iplot(kind='scatter',x='A',y='B',mode='markers',size=5,xTitle='A',yTitle='B')
# Out:
# <div>
#
#
#             <div id="9571158a-a0dc-489c-b718-cdb990f0619f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("9571158a-a0dc-489c-b718-cdb990f0619f")) {
#                     Plotly.newPlot(
#                         '9571158a-a0dc-489c-b718-cdb990f0619f',
# ...

# %% [markdown]
# # Bar Plot

# %%
df2.iplot(kind='bar',x='Category',y='Values',title='Bar plot of DF2 ')
# Out:
# <div>
#
#
#             <div id="b73a4199-64b4-4752-beb7-dc6ccb79ea34" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("b73a4199-64b4-4752-beb7-dc6ccb79ea34")) {
#                     Plotly.newPlot(
#                         'b73a4199-64b4-4752-beb7-dc6ccb79ea34',
#                         [{"marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "name": "Values", "orientation": "v", "text": "", "type": "bar", "x": ["A", "B", "C"], "y": [32, 43, 50]}],
# ...

# %%
df.sum().iplot(kind='bar',title='Bar of sum for each column of df')
# Out:
# <div>
#
#
#             <div id="e55eb840-dd29-4da9-9e60-a31d50b078b5" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("e55eb840-dd29-4da9-9e60-a31d50b078b5")) {
#                     Plotly.newPlot(
#                         'e55eb840-dd29-4da9-9e60-a31d50b078b5',
#                         [{"marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "name": "None", "orientation": "v", "text": "", "type": "bar", "x": ["A", "B", "C", "D"], "y": [10.887496711809039, 5.2307434015316945, 2.9437619866673232, 6.638814348300609]}],
# ...

# %% [markdown]
# # Box Plot

# %%
df.iplot(kind='box')
# Out:
# <div>
#
#
#             <div id="130db9e8-fe81-4ad3-a03d-21529b8a353a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("130db9e8-fe81-4ad3-a03d-21529b8a353a")) {
#                     Plotly.newPlot(
#                         '130db9e8-fe81-4ad3-a03d-21529b8a353a',
# ...

# %% [markdown]
# # 3D surface plot

# %%
df3=pd.DataFrame({'x':[1,2,3,4,5],'y':[10,20,30,20,10],'z':[5,4,3,2,1]})

# %%
df3
# Out:
#    x   y  z
# 0  1  10  5
# 1  2  20  4
# 2  3  30  3
# 3  4  20  2
# 4  5  10  1

# %%
df3.iplot(kind='surface',colorscale='rdylbu')
# Out:
# <div>
#
#
#             <div id="8518463e-400f-436a-ac46-f928a8ed79a9" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("8518463e-400f-436a-ac46-f928a8ed79a9")) {
#                     Plotly.newPlot(
#                         '8518463e-400f-436a-ac46-f928a8ed79a9',
# ...

# %% [markdown]
# # Histogram

# %%
#Creating histogram plot for column A of df
df['A'].iplot(kind='hist',bins=50)
# Out:
# <div>
#
#
#             <div id="883ae9ba-8ca8-4f55-ab22-8cdbc506e5c3" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("883ae9ba-8ca8-4f55-ab22-8cdbc506e5c3")) {
#                     Plotly.newPlot(
#                         '883ae9ba-8ca8-4f55-ab22-8cdbc506e5c3',
# ...

# %% [markdown]
# # Spread

# %% [markdown]
# This will be usefull for stock / forex plotting.

# %% [markdown]
# The spread is the differnce between the values plotted.

# %%
df[['A','B']].iplot(kind='spread')
# Out:
# <div>
#
#
#             <div id="0bd28745-7cb0-4e7a-be2b-63be06e9485a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("0bd28745-7cb0-4e7a-be2b-63be06e9485a")) {
#                     Plotly.newPlot(
#                         '0bd28745-7cb0-4e7a-be2b-63be06e9485a',
# ...

# %% [markdown]
# # Bubble plot

# %%
df.iplot(kind='bubble',x='A',y='B',size='C')
# Out:
# <div>
#
#
#             <div id="88a1c458-90a8-4b86-a308-a2494d1d80e2" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("88a1c458-90a8-4b86-a308-a2494d1d80e2")) {
#                     Plotly.newPlot(
#                         '88a1c458-90a8-4b86-a308-a2494d1d80e2',
# ...

# %% [markdown]
# # Scatter Matrix

# %% [markdown]
# Essentially the same thing as a pair plot

# %%
df.scatter_matrix()
# Out:
# <div>
#
#
#             <div id="979fdba7-de90-457f-949d-0946d95c9817" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("979fdba7-de90-457f-949d-0946d95c9817")) {
#                     Plotly.newPlot(
#                         '979fdba7-de90-457f-949d-0946d95c9817',
# ...
