# %% [raw]
# import seaborn as sns

# %%
# %matplotlib inline

# %%
#Note: Seaborn has a bunch of build in datasets that can be worked with
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# # Creating a Distribution Plot of the total bill

# %% [markdown]
# Note this type of plot can only be done for a single value (column) in the data frame
# This is representative of a historgram

# %%
sns.distplot(tips['total_bill'],kde=False,bins=40)

# %% [markdown]
# # Joint plot

# %% [markdown]
# Effectivly this type of plot combines 2 distribution plots usint bi variet data (2 variables)
# x variable / y variable and the data set

# %%
sns.jointplot(x='total_bill',y='tip',data=tips)

# %% [markdown]
# Changing the type of plot (kind)

# %%
#Note the darker the hexagon the more values are in it
sns.jointplot(x='total_bill',y='tip',data=tips, kind='hex')
#This has a liniar regression line created based in the data
sns.jointplot(x='total_bill',y='tip',data=tips, kind='reg')

# %% [markdown]
# # Pairplots

# %% [markdown]
# Pair plot is essentially a joint plot for every numerical values in a data frame

# %%
sns.pairplot(tips)

# %% [markdown]
# Adding a hue arrgument will color the plots based on the categorical argument of the hue

# %%
#Adding palette will futher style the plots
sns.pairplot(tips,hue='smoker',palette='RdBu')

# %% [markdown]
# # Kernal denisty estimation plot (KDE)

# %%
sns.kdeplot(tips['total_bill'])
